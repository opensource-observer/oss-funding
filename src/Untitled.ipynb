# %%
from google.cloud import bigquery
import os
import pandas as pd

# https://docs.opensource.observer/docs/get-started/
# add GCP project and credentials here

PROJECT = 'opensource-observer'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../gcp_credentials.json'
client = bigquery.Client()

# %%
query = f"""
select
    project_name,
    display_name
from `{PROJECT}.oso.projects_v1`
"""
results = client.query(query)
projects = results.to_dataframe()

# %%
DATA_DIR = '../data'
dataframes = []

for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file.lower().endswith('.csv'):
            file_path = os.path.join(root, file)
            try:
                csv = pd.read_csv(file_path)
                csv['file_path'] = file_path
                dataframes.append(csv)
            except Exception as e:
                print(f"Error reading {file_path}: {e}")

if dataframes:
    df = pd.concat(dataframes, ignore_index=True)
else:
    df = pd.DataFrame()
    print("No CSV files found.")

# %%
list_projects = df['to_project_name'].dropna().unique()
len(list_projects)
# Out:
# 649

# %%
for p in list_projects:
    if p not in projects['project_name'].unique():
        print(p)

# %%
df[df['to_project_name'] == 'scope-lift']
# Out:
# Empty DataFrame
# Columns: [to_project_name, amount, funding_date, from_funder_name, grant_pool_name, metadata, file_path]
# Index: []

# %%
import pandas as pd
import yaml
import json

# %%
DIR = "../data/funders/dao_drops/"

# %%
COLS = [
    "oso_slug",
    "project_name",
    "project_id",
    "project_url",
    "project_address",
    "funder_name",
    "funder_round_name",
    "funder_round_type",
    "funder_address",
    "funding_amount",
    "funding_currency",
    "funding_network",
    "funding_date"
]
prices = {
    ('ARB', '2023-12-01'): 1.75,
    ('ETH', '2023-10-19'): 2000,
    ('ETH', '2024-01-17'): 2500,
    ('ETH', '2024-04-30'): 3010,    
    ( 'OP', '2022-07-01'): 1.00,
    ( 'OP', '2022-11-01'): 1.25,
    ( 'OP', '2023-01-01'): 1.25,
    ( 'OP', '2023-02-01'): 1.50,
    ( 'OP', '2023-04-01'): 1.50,
    ( 'OP', '2023-05-01'): 1.50,
    ( 'OP', '2023-09-01'): 1.75,
    ( 'OP', '2024-01-01'): 3.50,
    ( 'OP', '2024-07-17'): 1.80,
}

# %%
def datify(x):

    if isinstance(x, str):
        if "/" in x:
            date = pd.to_datetime(x, dayfirst=False)
        elif "T" in x:
            x = x.split("T")[0]
            date = pd.to_datetime(x)
        elif ":" in x:
            x = x.split(" ")[0]
            date = pd.to_datetime(x)
        else:
            date = pd.to_datetime(x)
    else:
        date = pd.to_datetime(x.date())
    string = f"{date.year}-{str(date.month).zfill(2)}-{str(date.day).zfill(2)}"
    return string
    
def price(currency, date, amt):
    if pd.isna(amt):
        return 0
    if currency in ['DAI', 'USD']:
        return amt
    else:
        fx = prices.get((currency, date))
        return amt * fx

# %%
dao_drops = pd.read_csv(DIR + "dao_drops_grants.csv", index_col=0)

dao_drops.rename(columns={
    "Project": "project_name",
    "To": "project_address",
    "DAI": "funding_amount",
}, inplace=True)

dao_drops["project_id"] = None
dao_drops["project_url"] = "https://daodrops.io/"

dao_drops["funder_name"] = "DAO Drops (dOrg)"
dao_drops["funder_address"] = "0xafe5f7a1d1c173b311047cdc93729013ad03de0c"
dao_drops["funding_currency"] = "DAI"
dao_drops["funding_network"] = "mainnet"
dao_drops["funder_round_type"] = "Retroactive"
dao_drops["funder_round_name"] = "Round 1"
dao_drops["funding_date"] = pd.to_datetime("2023-03-29")

temp = dao_drops[COLS].copy()

temp['funding_date'] = temp['funding_date'].apply(datify)
temp['funding_usd'] = temp.apply(
    lambda x: price(x['funding_currency'], x['funding_date'], x['funding_amount']), axis=1)

temp
# Out:
#                         oso_slug  \
# 0                         giveth
# 1                            NaN
# 2                      ethers-io
# 3               metagame-metafam
# 4                          rotki
# 5                       eth-limo
# 6                     gooddollar
# 7                       l2planet
# 8              gashawk-corpus-io
# 9                            NaN
# 10                     otterscan
# 11                        lexdao
# 12                  lightclients
# 13                           NaN
# 14                       metagov
# 15                           NaN
# 16                    givepraise
# 17               bankless-africa
# 18             solady-vectorized
# 19  ethereum-attestation-service
# 20                       metagov
# 21                    scope-lift
# 22                           NaN
# 23                           NaN
# 24               public-assembly
# 25                       sablier
# 26                           NaN
# 27                           NaN
# 28                    sourcecred
# 29                         1hive
# 30                           NaN
# 31                           NaN
# 32                           NaN
# 33                         rndao
# 34                           NaN
# 35                      spect-ai
# 36                           NaN
# 37                           NaN
# 38                           NaN
# 39                           NaN
# 40                     journodao
# 41                      urbanika
# 42                           NaN
# 43                           NaN
# 44                           NaN
# 45                           NaN
# 46                           NaN
# 47                           NaN
# 48                           NaN
# 49                  crypto-stats
# 50                           NaN
# 51                       kredeum
# 52                           NaN
# 53                           NaN
# 54                           NaN
# 55                           NaN
# 56                           NaN
#
#                                          project_name project_id  \
# 0                                              Giveth       None
# 1                                        DeFi Library       None
# 2                                           ethers.js       None
# 3                                            Metagame       None
# 4                                               Rotki       None
# 5                                            eth.limo       None
# 6                                          GoodDollar       None
# 7                                           L2 Planet       None
# 8                                             GasHawk       None
# 9                                             LauNaMu       None
# 10                                          Otterscan       None
# 11                                               Kali       None
# 12                                             Kevlar       None
# 13                                            Bspeak!       None
# 14                                            Metagov       None
# 15                                     Hudson Jameson       None
# 16                                             Praise       None
# 17                                    Bankless Africa       None
# 18                                             Solady       None
# 19                 Ethereum Attestation Service (EAS)       None
# 20                                            DAOstar       None
# 21                                              Umbra       None
# 22                                       Travis Wyche       None
# 23                                       Natalie Crue       None
# 24                                    Public Assembly       None
# 25                                          Paul Berg       None
# 26                                     Other Internet       None
# 27                                   Zargham - cadCAD       None
# 28                                         SourceCred       None
# 29                                            Gardens       None
# 30                                    Cripto Curiosas       None
# 31                       Anticapture - Spencer Graham       None
# 32                                      L3GENDARY DAO       None
# 33                                              RnDAO       None
# 34                                         Web3bridge       None
# 35                                              Spect       None
# 36                                         LaloCripto       None
# 37                                             MedDAO       None
# 38                                      Carlos Melgar       None
# 56  DAO Drops (dOrg)           Round 1       Retroactive
#
#                                 funder_address  funding_amount  \
# 0   0xafe5f7a1d1c173b311047cdc93729013ad03de0c           18186
# 1   0xafe5f7a1d1c173b311047cdc93729013ad03de0c           14373
# 2   0xafe5f7a1d1c173b311047cdc93729013ad03de0c           11801
# 3   0xafe5f7a1d1c173b311047cdc93729013ad03de0c           11287
# 4   0xafe5f7a1d1c173b311047cdc93729013ad03de0c           10863
# 5   0xafe5f7a1d1c173b311047cdc93729013ad03de0c           10530
# 6   0xafe5f7a1d1c173b311047cdc93729013ad03de0c            9199
# 7   0xafe5f7a1d1c173b311047cdc93729013ad03de0c            9078
# 8   0xafe5f7a1d1c173b311047cdc93729013ad03de0c            8654
# 9   0xafe5f7a1d1c173b311047cdc93729013ad03de0c            7898
# 10  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            7716
# 11  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            7656
# 12  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            6808
# 13  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            6808
# 14  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            6112
# 15  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            6022
# 16  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            5326
# 17  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            4690
# 18  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            4690
# 19  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            4539
# 20  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            4327
# 21  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            4206
# 22  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            4145
# 23  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            3752
# 24  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            3328
# 25  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            3298
# 26  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            3117
# 27  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            3056
# 28  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            3056
# 29  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            3026
# 30  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            2693
# 31  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            2663
# 32  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            2633
# 33  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            2481
# 34  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            2239
# 35  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            2179
# 36  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            2179
# 37  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1906
# 38  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1876
# 39  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1816
# 40  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1785
# 41  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1725
# 42  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1695
# 43  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1664
# 44  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1634
# 45  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1483
# 46  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1452
# 47  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1422
# 48  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1331
# 49  0xafe5f7a1d1c173b311047cdc93729013ad03de0c            1271
# 50  0xafe5f7a1d1c173b311047cdc93729013ad03de0c             908
# 51  0xafe5f7a1d1c173b311047cdc93729013ad03de0c             817
# 52  0xafe5f7a1d1c173b311047cdc93729013ad03de0c             787
# 53  0xafe5f7a1d1c173b311047cdc93729013ad03de0c             605
# 54  0xafe5f7a1d1c173b311047cdc93729013ad03de0c             484
# 55  0xafe5f7a1d1c173b311047cdc93729013ad03de0c             393
# 56  0xafe5f7a1d1c173b311047cdc93729013ad03de0c             333
#
#    funding_currency funding_network funding_date  funding_usd
# 0               DAI         mainnet   2023-03-29        18186
# 1               DAI         mainnet   2023-03-29        14373
# 2               DAI         mainnet   2023-03-29        11801
# 3               DAI         mainnet   2023-03-29        11287
# 4               DAI         mainnet   2023-03-29        10863
# 5               DAI         mainnet   2023-03-29        10530
# 6               DAI         mainnet   2023-03-29         9199
# 7               DAI         mainnet   2023-03-29         9078
# 8               DAI         mainnet   2023-03-29         8654
# 9               DAI         mainnet   2023-03-29         7898
# 10              DAI         mainnet   2023-03-29         7716
# 11              DAI         mainnet   2023-03-29         7656
# 12              DAI         mainnet   2023-03-29         6808
# 13              DAI         mainnet   2023-03-29         6808
# 14              DAI         mainnet   2023-03-29         6112
# 15              DAI         mainnet   2023-03-29         6022
# 16              DAI         mainnet   2023-03-29         5326
# 17              DAI         mainnet   2023-03-29         4690
# 18              DAI         mainnet   2023-03-29         4690
# 19              DAI         mainnet   2023-03-29         4539
# 20              DAI         mainnet   2023-03-29         4327
# 21              DAI         mainnet   2023-03-29         4206
# 22              DAI         mainnet   2023-03-29         4145
# 23              DAI         mainnet   2023-03-29         3752
# 24              DAI         mainnet   2023-03-29         3328
# 25              DAI         mainnet   2023-03-29         3298
# 26              DAI         mainnet   2023-03-29         3117
# 27              DAI         mainnet   2023-03-29         3056
# 28              DAI         mainnet   2023-03-29         3056
# 29              DAI         mainnet   2023-03-29         3026
# 30              DAI         mainnet   2023-03-29         2693
# 31              DAI         mainnet   2023-03-29         2663
# 32              DAI         mainnet   2023-03-29         2633
# 33              DAI         mainnet   2023-03-29         2481
# 34              DAI         mainnet   2023-03-29         2239
# 35              DAI         mainnet   2023-03-29         2179
# 36              DAI         mainnet   2023-03-29         2179
# 37              DAI         mainnet   2023-03-29         1906
# 38              DAI         mainnet   2023-03-29         1876
# 39              DAI         mainnet   2023-03-29         1816
# 40              DAI         mainnet   2023-03-29         1785
# 41              DAI         mainnet   2023-03-29         1725
# 42              DAI         mainnet   2023-03-29         1695
# 43              DAI         mainnet   2023-03-29         1664
# 44              DAI         mainnet   2023-03-29         1634
# 45              DAI         mainnet   2023-03-29         1483
# 46              DAI         mainnet   2023-03-29         1452
# 47              DAI         mainnet   2023-03-29         1422
# 48              DAI         mainnet   2023-03-29         1331
# 49              DAI         mainnet   2023-03-29         1271
# 50              DAI         mainnet   2023-03-29          908
# 51              DAI         mainnet   2023-03-29          817
# 52              DAI         mainnet   2023-03-29          787
# 53              DAI         mainnet   2023-03-29          605
# 54              DAI         mainnet   2023-03-29          484
# 55              DAI         mainnet   2023-03-29          393
# 56              DAI         mainnet   2023-03-29          333

# %%
df = temp[['funding_usd', 'funding_date', 'funder_name', 'oso_slug', 'funder_round_name']].copy()

df.rename(columns={
    'funder_name': 'from_funder_name',
    'oso_slug': 'to_project_name',
    'funder_round_name': 'grant_pool_name',
    'funding_usd': 'amount'
}, inplace=True)

#df['to_project_name'] = df['to_project_name'].fillna('na') 
df['from_funder_name'] = df['from_funder_name'].apply(lambda x: x.lower().replace(' ','_'))
df['grant_pool_name'] = df['grant_pool_name'].apply(lambda x: x.lower().replace(' ','_'))

def make_metadata(data):
    metadata = {
        'application_name': data['project_name'],
        'application_url': data['project_url'],
        'token_amount': data['funding_amount'],
        'token_unit': data['funding_currency']
    }
    return json.dumps(metadata)
    
    

df['metadata'] = temp.apply(make_metadata, axis=1)

for x in df['grant_pool_name'].unique():
    print("-",x)
# Out:
# - round_1

# %% [markdown]
# - funding_date
# - from_funder_name
# - to_project_name
# - grant_pool_name
# - amount_usd
# - metadata

# %%
for x in df['grant_pool_name'].unique():
    dff = df[df['grant_pool_name'] == x].set_index('to_project_name', drop=True)
    dff.sort_index().to_csv(f"{DIR}uploads/{x}.csv")
